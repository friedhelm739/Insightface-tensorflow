# %%
import tensorflow as tf
from train.train_tool import arcface_loss,read_single_tfrecord,average_gradients
from core import Arcface_model,config
import time
import os
from evaluate.evaluate import evaluation,load_bin


def train(image,label,train_phase_dropout,train_phase_bn, images_batch, images_f_batch, issame_list_batch):

    train_images_split = tf.split(image, config.gpu_num)
    train_labels_split = tf.split(label, config.gpu_num)      
    
    global_step = tf.Variable(name='global_step', initial_value=0, trainable=False)
    inc_op = tf.assign_add(global_step, 1, name='increment_global_step')    
    scale = int(512.0/batch_size)
    lr_steps = [scale*s for s in config.lr_steps]
    lr_values = [v/scale for v in config.lr_values]
    lr = tf.train.piecewise_constant(global_step, boundaries=lr_steps, values=lr_values, name='lr_schedule')
    opt = tf.train.MomentumOptimizer(learning_rate=lr, momentum=config.momentum)

    embds = []
    logits = []
    inference_loss = []
    wd_loss = []
    total_train_loss = []
    pred = []
    tower_grads = []
    update_ops = []
    
    for i in range(config.gpu_num):
        sub_train_images = train_images_split[i]
        sub_train_labels = train_labels_split[i]
        
        with tf.device("/gpu:%d"%(i)):
            with tf.variable_scope(tf.get_variable_scope(),reuse=(i>0)):
                
                net, end_points = Arcface_model.get_embd(sub_train_images, train_phase_dropout, train_phase_bn,config.model_params)
                        
                logit = arcface_loss(net,sub_train_labels,config.s,config.m)
                arc_loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits = logit , labels = sub_train_labels))
                L2_loss = tf.reduce_sum(tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES))
                train_loss = arc_loss + L2_loss
                
                pred.append(tf.to_int32(tf.argmax(tf.nn.softmax(logit),axis=1)))
                tower_grads.append(opt.compute_gradients(train_loss))
                update_ops.append(tf.get_collection(tf.GraphKeys.UPDATE_OPS))
                
                embds.append(net)
                logits.append(logit)
                inference_loss.append(arc_loss)
                wd_loss.append(L2_loss)
                total_train_loss.append(train_loss)

    embds = tf.concat(embds, axis=0)
    logits = tf.concat(logits, axis=0)
    pred = tf.concat(pred, axis=0)
    wd_loss = tf.add_n(wd_loss)/config.gpu_num
    inference_loss = tf.add_n(inference_loss)/config.gpu_num
    
    train_ops = [opt.apply_gradients(average_gradients(tower_grads))]
    train_ops.extend(update_ops)
    train_op = tf.group(*train_ops) 
    
    with tf.name_scope('loss'):
        train_loss = tf.add_n(total_train_loss)/config.gpu_num
        tf.summary.scalar('train_loss',train_loss)    

    with tf.name_scope('accuracy'):
        train_accuracy = tf.reduce_mean(tf.cast(tf.equal(pred, label), tf.float32))
        tf.summary.scalar('train_accuracy',train_accuracy) 
        
    saver=tf.train.Saver(max_to_keep=20)
    merged=tf.summary.merge_all() 
    
    train_images,train_labels=read_single_tfrecord(addr,batch_size,img_size)
    
    tf_config = tf.ConfigProto(allow_soft_placement=True)
    tf_config.gpu_options.allow_growth = True
    with tf.Session(config=tf_config) as sess:
        sess.run((tf.global_variables_initializer(),
                  tf.local_variables_initializer()))
        coord = tf.train.Coordinator()
        threads = tf.train.start_queue_runners(sess=sess,coord=coord)
        writer_train=tf.summary.FileWriter(model_path,sess.graph)
        print("start")
        try:
            for i in range(1,train_step):                
                image_batch,label_batch=sess.run([train_images,train_labels])
                sess.run([train_op,inc_op],feed_dict={image:image_batch,label:label_batch,train_phase_dropout:True,train_phase_bn:True})
                
                if(i%100==0):
                    summary=sess.run(merged,feed_dict={image:image_batch,label:label_batch,train_phase_dropout:True,train_phase_bn:True})
                    writer_train.add_summary(summary,i)
                    
                if(i%1000==0):
                    print('times: ',i)    
#                     print('train_accuracy: ',sess.run(train_accuracy,feed_dict={image:image_batch,label:label_batch,train_phase_dropout:True,train_phase_bn:True}))
#                     print('train_loss: ',sess.run(train_loss,{image:image_batch,label:label_batch,train_phase_dropout:True,train_phase_bn:True}))       
                    print('time: ',time.time()-begin)
                    
                if(i%5000==0):
                    f.write("itrations: %d"%(i)+'\n')
                    for idx in range(len(eval_datasets)):
                        tpr, fpr, accuracy, best_thresholds = evaluation(sess, images_batch[idx], images_f_batch[idx], issame_list_batch[idx], batch_size, img_size, dropout_flag=config.eval_dropout_flag, bn_flag=config.eval_bn_flag, embd=embds, image=image, train_phase_dropout=train_phase_dropout, train_phase_bn=train_phase_bn) 
                        print("%s datasets get %.3f acc"%(eval_datasets[idx].split("/")[-1].split(".")[0],accuracy))
                        f.write("\t %s \t %.3f \t \t "%(eval_datasets[idx].split("/")[-1].split(".")[0],accuracy)+str(best_thresholds)+'\n')
                    f.write('\n')
                    
                if((i>150000)&(i%config.model_save_gap==0)):
                    saver.save(sess,os.path.join(model_path,model_name),global_step=i)
        except  tf.errors.OutOfRangeError:
            print("finished")
        finally:
            coord.request_stop()
            writer_train.close()
        coord.join(threads)
        f.close()
        
            
def main():
    
    with tf.name_scope('input'):
        image = tf.placeholder(tf.float32,[batch_size,img_size,img_size,3],name='image')
        label = tf.placeholder(tf.int32,[batch_size],name='label')
        train_phase_dropout = tf.placeholder(dtype=tf.bool, shape=None, name='train_phase_dropout')
        train_phase_bn = tf.placeholder(dtype=tf.bool, shape=None, name='train_phase_bn') 

    images_batch = []
    images_f_batch = []
    issame_list_batch = []
    for dataset_path in eval_datasets:
        images, images_f, issame_list = load_bin(dataset_path, img_size)    
        images_batch.append(images)
        images_f_batch.append(images_f)
        issame_list_batch.append(issame_list)
    
    train(image,label, train_phase_dropout, train_phase_bn, images_batch, images_f_batch, issame_list_batch)


if __name__ == "__main__":
    
    img_size = config.img_size
    batch_size = config.batch_size
    addr = config.addrt
    model_name = config.model_name
    train_step = config.train_step
    model_path = config.model_patht
    eval_datasets = config.eval_datasets
    
    begin=time.time()
    
    f = open("./eval_record.txt", 'w')
    f.write("\t dataset \t accuracy \t best_thresholds \t"+'\n')    
    main()
# tensorboard --logdir=/home/dell/Desktop/insightface/model/Arcface_model/
# Out:
# /home/dell/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From /home/dell/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
# reading ./data/lfw.bin
# done!
# reading ./data/agedb_30.bin
# done!
# reading ./data/calfw.bin
# done!
# reading ./data/cfp_ff.bin
# done!
# reading ./data/cfp_fp.bin
# done!
# reading ./data/cplfw.bin
# done!
# reading ./data/lfw_face.db
# done!
# start
# times:  1000
# time:  733.7754483222961
# times:  2000
# time:  1272.9938457012177
# times:  3000
# time:  1811.6488132476807
# times:  4000
# time:  2350.833826303482
# times:  5000
# time:  2890.7193360328674
# lfw datasets get 0.947 acc
# agedb_30 datasets get 0.774 acc
# calfw datasets get 0.822 acc
# cfp_ff datasets get 0.943 acc
# cfp_fp datasets get 0.793 acc
# cplfw datasets get 0.730 acc
# lfw_face datasets get 0.774 acc
# times:  6000
# time:  3650.346690416336
# times:  7000
# time:  4190.842154979706
# times:  8000
# time:  4737.433312654495
# times:  9000
# time:  5276.991191864014
# times:  10000
# time:  5816.671426773071
# lfw datasets get 0.955 acc
# agedb_30 datasets get 0.819 acc
# calfw datasets get 0.843 acc
# cfp_ff datasets get 0.958 acc
# cfp_fp datasets get 0.826 acc
# cplfw datasets get 0.734 acc
# lfw_face datasets get 0.821 acc
# times:  11000
# time:  6574.851009130478
# times:  12000
# time:  7113.510889053345
# times:  13000
# time:  7653.806161165237
# times:  14000
# time:  8193.273201227188
# times:  15000
# time:  8734.467559814453
# lfw datasets get 0.963 acc
# agedb_30 datasets get 0.849 acc
# calfw datasets get 0.850 acc
# cfp_ff datasets get 0.963 acc
# cfp_fp datasets get 0.815 acc
# cplfw datasets get 0.726 acc
# lfw_face datasets get 0.822 acc
# times:  16000
# time:  9491.828449487686
# times:  17000
# time:  10045.581939220428
# times:  18000
# time:  10584.112287521362
# times:  19000
# time:  11123.358433485031
# times:  20000
# time:  11662.643212556839
# lfw datasets get 0.976 acc
# agedb_30 datasets get 0.861 acc
# calfw datasets get 0.880 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.870 acc
# cplfw datasets get 0.787 acc
# lfw_face datasets get 0.863 acc
# times:  21000
# time:  12420.525582790375
# times:  22000
# time:  12960.293102741241
# times:  23000
# time:  13500.982472419739
# times:  24000
# time:  14040.133050203323
# times:  25000
# time:  14580.666088104248
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.864 acc
# calfw datasets get 0.876 acc
# cfp_ff datasets get 0.975 acc
# cfp_fp datasets get 0.865 acc
# cplfw datasets get 0.797 acc
# lfw_face datasets get 0.879 acc
# times:  26000
# time:  15338.383795261383
# times:  27000
# time:  15877.72078537941
# times:  28000
# time:  16415.440347909927
# times:  29000
# time:  16955.48869895935
# times:  30000
# time:  17497.043640613556
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.880 acc
# calfw datasets get 0.883 acc
# cfp_ff datasets get 0.982 acc
# cfp_fp datasets get 0.883 acc
# cplfw datasets get 0.803 acc
# lfw_face datasets get 0.881 acc
# times:  31000
# time:  18254.799028873444
# times:  32000
# time:  18794.12455677986
# times:  33000
# time:  19333.46679353714
# times:  34000
# time:  19872.181725502014
# times:  35000
# time:  20412.506355285645
# lfw datasets get 0.983 acc
# agedb_30 datasets get 0.894 acc
# calfw datasets get 0.903 acc
# cfp_ff datasets get 0.984 acc
# cfp_fp datasets get 0.876 acc
# cplfw datasets get 0.810 acc
# lfw_face datasets get 0.875 acc
# times:  36000
# time:  21169.51073741913
# times:  37000
# time:  21708.54978442192
# times:  38000
# time:  22248.700023651123
# times:  39000
# time:  22789.876505851746
# times:  40000
# time:  23330.01781153679
# lfw datasets get 0.984 acc
# agedb_30 datasets get 0.898 acc
# calfw datasets get 0.899 acc
# cfp_ff datasets get 0.986 acc
# cfp_fp datasets get 0.893 acc
# cplfw datasets get 0.816 acc
# lfw_face datasets get 0.887 acc
# times:  41000
# time:  24089.046011686325
# times:  42000
# time:  24628.741590738297
# times:  43000
# time:  25168.832225322723
# times:  44000
# time:  25709.759279727936
# times:  45000
# time:  26249.819321632385
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.895 acc
# calfw datasets get 0.893 acc
# cfp_ff datasets get 0.983 acc
# cfp_fp datasets get 0.899 acc
# cplfw datasets get 0.819 acc
# lfw_face datasets get 0.888 acc
# times:  46000
# time:  27007.050149679184
# times:  47000
# time:  27544.713828086853
# times:  48000
# time:  28084.59315752983
# times:  49000
# time:  28623.906613588333
# times:  50000
# time:  29161.84468436241
# lfw datasets get 0.984 acc
# agedb_30 datasets get 0.895 acc
# calfw datasets get 0.911 acc
# cfp_ff datasets get 0.986 acc
# cfp_fp datasets get 0.902 acc
# cplfw datasets get 0.827 acc
# lfw_face datasets get 0.895 acc
# times:  51000
# time:  29919.292730093002
# times:  52000
# time:  30457.088832616806
# times:  53000
# time:  30996.592750787735
# times:  54000
# time:  31537.122571468353
# times:  55000
# time:  32076.46738743782
# lfw datasets get 0.989 acc
# agedb_30 datasets get 0.897 acc
# calfw datasets get 0.909 acc
# cfp_ff datasets get 0.985 acc
# cfp_fp datasets get 0.906 acc
# cplfw datasets get 0.839 acc
# lfw_face datasets get 0.903 acc
# times:  56000
# time:  32833.29942584038
# times:  57000
# time:  33372.368836164474
# times:  58000
# time:  33911.72071433067
# times:  59000
# time:  34450.97946500778
# times:  60000
# time:  34989.994512319565
# lfw datasets get 0.986 acc
# agedb_30 datasets get 0.898 acc
# calfw datasets get 0.897 acc
# cfp_ff datasets get 0.987 acc
# cfp_fp datasets get 0.908 acc
# cplfw datasets get 0.830 acc
# lfw_face datasets get 0.893 acc
# times:  61000
# time:  35746.953823804855
# times:  62000
# time:  36286.03223991394
# times:  63000
# time:  36826.385812044144
# times:  64000
# time:  37365.24087929726
# times:  65000
# time:  37904.22760796547
# lfw datasets get 0.983 acc
# agedb_30 datasets get 0.901 acc
# calfw datasets get 0.898 acc
# cfp_ff datasets get 0.985 acc
# cfp_fp datasets get 0.907 acc
# cplfw datasets get 0.828 acc
# lfw_face datasets get 0.895 acc
# times:  66000
# time:  38659.62300014496
# times:  67000
# time:  39197.937368154526
# times:  68000
# time:  39736.60343790054
# times:  69000
# time:  40276.26714634895
# times:  70000
# time:  40815.835602760315
# lfw datasets get 0.988 acc
# agedb_30 datasets get 0.905 acc
# calfw datasets get 0.902 acc
# cfp_ff datasets get 0.983 acc
# cfp_fp datasets get 0.907 acc
# cplfw datasets get 0.833 acc
# lfw_face datasets get 0.901 acc
# times:  71000
# time:  41574.200468063354
# times:  72000
# time:  42112.98706436157
# times:  73000
# time:  42651.9228515625
# times:  74000
# time:  43189.85583257675
# times:  75000
# time:  43728.230805397034
# lfw datasets get 0.989 acc
# agedb_30 datasets get 0.904 acc
# calfw datasets get 0.907 acc
# cfp_ff datasets get 0.988 acc
# cfp_fp datasets get 0.921 acc
# cplfw datasets get 0.845 acc
# lfw_face datasets get 0.905 acc
# times:  76000
# time:  44485.55852031708
# times:  77000
# time:  45024.10127878189
# times:  78000
# time:  45563.276758909225
# times:  79000
# time:  46101.940135240555
# times:  80000
# time:  46640.79973721504
# lfw datasets get 0.984 acc
# agedb_30 datasets get 0.897 acc
# calfw datasets get 0.885 acc
# cfp_ff datasets get 0.984 acc
# cfp_fp datasets get 0.917 acc
# cplfw datasets get 0.828 acc
# lfw_face datasets get 0.894 acc
# times:  81000
# time:  47398.36377954483
# times:  82000
# time:  47937.269918203354
# times:  83000
# time:  48477.47211265564
# times:  84000
# time:  49017.273278951645
# times:  85000
# time:  49556.05730009079
# lfw datasets get 0.984 acc
# agedb_30 datasets get 0.909 acc
# calfw datasets get 0.902 acc
# cfp_ff datasets get 0.984 acc
# cfp_fp datasets get 0.915 acc
# cplfw datasets get 0.849 acc
# lfw_face datasets get 0.903 acc
# times:  86000
# time:  50313.23059630394
# times:  87000
# time:  50851.64265418053
# times:  88000
# time:  51391.02791213989
# times:  89000
# time:  51929.4564242363
# times:  90000
# time:  52469.637796640396
# lfw datasets get 0.988 acc
# agedb_30 datasets get 0.906 acc
# calfw datasets get 0.898 acc
# cfp_ff datasets get 0.986 acc
# cfp_fp datasets get 0.922 acc
# cplfw datasets get 0.838 acc
# lfw_face datasets get 0.897 acc
# times:  91000
# time:  53227.088572502136
# times:  92000
# time:  53765.237335681915
# times:  93000
# time:  54306.09609866142
# times:  94000
# time:  54844.7897233963
# times:  95000
# time:  55383.876834869385
# lfw datasets get 0.984 acc
# agedb_30 datasets get 0.906 acc
# calfw datasets get 0.890 acc
# cfp_ff datasets get 0.984 acc
# cfp_fp datasets get 0.914 acc
# cplfw datasets get 0.829 acc
# lfw_face datasets get 0.897 acc
# times:  96000
# time:  56140.9234855175
# times:  97000
# time:  56679.2535970211
# times:  98000
# time:  57218.10208916664
# times:  99000
# time:  57758.682121515274
# times:  100000
# time:  58298.09419798851
# lfw datasets get 0.983 acc
# agedb_30 datasets get 0.903 acc
# calfw datasets get 0.901 acc
# cfp_ff datasets get 0.983 acc
# cfp_fp datasets get 0.914 acc
# cplfw datasets get 0.847 acc
# lfw_face datasets get 0.901 acc
# times:  101000
# time:  59054.986095666885
# times:  102000
# time:  59593.79058718681
# times:  103000
# time:  60132.30726027489
# times:  104000
# time:  60671.68413114548
# times:  105000
# time:  61209.03508281708
# lfw datasets get 0.988 acc
# agedb_30 datasets get 0.910 acc
# calfw datasets get 0.904 acc
# cfp_ff datasets get 0.984 acc
# cfp_fp datasets get 0.919 acc
# cplfw datasets get 0.836 acc
# lfw_face datasets get 0.899 acc
# times:  106000
# time:  61964.09339737892
# times:  107000
# time:  62501.722397089005
# times:  108000
# time:  63040.20493555069
# times:  109000
# time:  63579.07530212402
# times:  110000
# time:  64118.71972990036
# lfw datasets get 0.984 acc
# agedb_30 datasets get 0.900 acc
# calfw datasets get 0.887 acc
# cfp_ff datasets get 0.985 acc
# cfp_fp datasets get 0.916 acc
# cplfw datasets get 0.833 acc
# lfw_face datasets get 0.892 acc
# times:  111000
# time:  64875.414964437485
# times:  112000
# time:  65413.51819872856
# times:  113000
# time:  65951.86723041534
# times:  114000
# time:  66492.13868379593
# times:  115000
# time:  67031.99485945702
# lfw datasets get 0.985 acc
# agedb_30 datasets get 0.905 acc
# calfw datasets get 0.901 acc
# cfp_ff datasets get 0.985 acc
# cfp_fp datasets get 0.918 acc
# cplfw datasets get 0.835 acc
# lfw_face datasets get 0.893 acc
# times:  116000
# time:  67789.54975390434
# times:  117000
# time:  68327.45491099358
# times:  118000
# time:  68865.55631399155
# times:  119000
# time:  69404.78423190117
# times:  120000
# time:  69943.6648516655
# lfw datasets get 0.985 acc
# agedb_30 datasets get 0.904 acc
# calfw datasets get 0.898 acc
# cfp_ff datasets get 0.984 acc
# cfp_fp datasets get 0.917 acc
# cplfw datasets get 0.838 acc
# lfw_face datasets get 0.900 acc
# times:  121000
# time:  70717.63136959076
# times:  122000
# time:  71257.64632701874
# times:  123000
# time:  71796.7503964901
# times:  124000
# time:  72335.73447656631
# times:  125000
# time:  72875.55673384666
# lfw datasets get 0.984 acc
# agedb_30 datasets get 0.896 acc
# calfw datasets get 0.900 acc
# cfp_ff datasets get 0.983 acc
# cfp_fp datasets get 0.919 acc
# cplfw datasets get 0.842 acc
# lfw_face datasets get 0.899 acc
# times:  126000
# time:  73631.63395237923
# times:  127000
# time:  74170.35347557068
# times:  128000
# time:  74708.82078289986
# times:  129000
# time:  75248.26930379868
# times:  130000
# time:  75786.81085062027
# lfw datasets get 0.984 acc
# agedb_30 datasets get 0.898 acc
# calfw datasets get 0.889 acc
# cfp_ff datasets get 0.985 acc
# cfp_fp datasets get 0.919 acc
# cplfw datasets get 0.831 acc
# lfw_face datasets get 0.894 acc
# times:  131000
# time:  76543.60248208046
# times:  132000
# time:  77082.33626651764
# times:  133000
# time:  77621.4225564003
# times:  134000
# time:  78161.20020270348
# times:  135000
# time:  78700.80214262009
# lfw datasets get 0.986 acc
# agedb_30 datasets get 0.894 acc
# calfw datasets get 0.902 acc
# cfp_ff datasets get 0.983 acc
# cfp_fp datasets get 0.917 acc
# cplfw datasets get 0.839 acc
# lfw_face datasets get 0.891 acc
# times:  136000
# time:  79457.0035674572
# times:  137000
# time:  79995.13260960579
# times:  138000
# time:  80534.07853865623
# times:  139000
# time:  81074.276689291
# times:  140000
# time:  81613.3086078167
# lfw datasets get 0.987 acc
# agedb_30 datasets get 0.903 acc
# calfw datasets get 0.894 acc
# cfp_ff datasets get 0.983 acc
# cfp_fp datasets get 0.920 acc
# cplfw datasets get 0.839 acc
# lfw_face datasets get 0.899 acc
# times:  141000
# time:  82370.61487293243
# times:  142000
# time:  82911.31118297577
# times:  143000
# time:  83450.07562112808
# times:  144000
# time:  83989.65846514702
# times:  145000
# time:  84528.96154332161
# lfw datasets get 0.986 acc
# agedb_30 datasets get 0.894 acc
# calfw datasets get 0.883 acc
# cfp_ff datasets get 0.982 acc
# cfp_fp datasets get 0.919 acc
# cplfw datasets get 0.836 acc
# lfw_face datasets get 0.907 acc
# times:  146000
# time:  85284.91789197922
# times:  147000
# time:  85823.12779927254
# times:  148000
# time:  86363.1253426075
# times:  149000
# time:  86901.11332082748
# times:  150000
# time:  87440.69015145302
# lfw datasets get 0.986 acc
# agedb_30 datasets get 0.902 acc
# calfw datasets get 0.903 acc
# cfp_ff datasets get 0.984 acc
# cfp_fp datasets get 0.910 acc
# cplfw datasets get 0.841 acc
# lfw_face datasets get 0.897 acc
# times:  151000
# time:  88197.35982775688
# times:  152000
# time:  88735.83613920212
# times:  153000
# time:  89274.31259417534
# times:  154000
# time:  89812.41234707832
# times:  155000
# time:  90351.0630364418
# lfw datasets get 0.983 acc
# agedb_30 datasets get 0.900 acc
# calfw datasets get 0.902 acc
# cfp_ff datasets get 0.985 acc
# cfp_fp datasets get 0.915 acc
# cplfw datasets get 0.835 acc
# lfw_face datasets get 0.893 acc
# times:  156000
# time:  91108.42704319954
# times:  157000
# time:  91646.59562325478
# times:  158000
# time:  92186.08401751518
# times:  159000
# time:  92725.78218340874
# times:  160000
# time:  93265.51345825195
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.896 acc
# calfw datasets get 0.880 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.901 acc
# cplfw datasets get 0.825 acc
# lfw_face datasets get 0.883 acc
# times:  161000
# time:  94024.92673182487
# times:  162000
# time:  94563.77109026909
# times:  163000
# time:  95104.18612861633
# times:  164000
# time:  95644.1193408966
# times:  165000
# time:  96198.79953193665
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.902 acc
# calfw datasets get 0.898 acc
# cfp_ff datasets get 0.981 acc
# cfp_fp datasets get 0.909 acc
# cplfw datasets get 0.836 acc
# lfw_face datasets get 0.884 acc
# times:  166000
# time:  96955.66812705994
# times:  167000
# time:  97495.81360936165
# times:  168000
# time:  98036.21675395966
# times:  169000
# time:  98576.62751960754
# times:  170000
# time:  99116.65451169014
# lfw datasets get 0.984 acc
# agedb_30 datasets get 0.900 acc
# calfw datasets get 0.905 acc
# cfp_ff datasets get 0.986 acc
# cfp_fp datasets get 0.916 acc
# cplfw datasets get 0.843 acc
# lfw_face datasets get 0.885 acc
# times:  171000
# time:  99873.67668700218
# times:  172000
# time:  100413.3139128685
# times:  173000
# time:  100951.47030472755
# times:  174000
# time:  101489.90582156181
# times:  175000
# time:  102029.55381774902
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.885 acc
# calfw datasets get 0.887 acc
# cfp_ff datasets get 0.985 acc
# cfp_fp datasets get 0.909 acc
# cplfw datasets get 0.833 acc
# lfw_face datasets get 0.883 acc
# times:  176000
# time:  102786.5225121975
# times:  177000
# time:  103324.5352883339
# times:  178000
# time:  103863.98338770866
# times:  179000
# time:  104403.15573525429
# times:  180000
# time:  104942.60030913353
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.897 acc
# calfw datasets get 0.888 acc
# cfp_ff datasets get 0.983 acc
# cfp_fp datasets get 0.917 acc
# cplfw datasets get 0.829 acc
# lfw_face datasets get 0.884 acc
# times:  181000
# time:  105720.65649485588
# times:  182000
# time:  106258.32123351097
# times:  183000
# time:  106795.5236363411
# times:  184000
# time:  107334.22600197792
# times:  185000
# time:  107872.2233889103
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.896 acc
# calfw datasets get 0.891 acc
# cfp_ff datasets get 0.984 acc
# cfp_fp datasets get 0.908 acc
# cplfw datasets get 0.827 acc
# lfw_face datasets get 0.876 acc
# times:  186000
# time:  108630.0338666439
# times:  187000
# time:  109173.91305708885
# times:  188000
# time:  109714.2114803791
# times:  189000
# time:  110253.75091671944
# times:  190000
# time:  110793.29492163658
# lfw datasets get 0.984 acc
# agedb_30 datasets get 0.893 acc
# calfw datasets get 0.901 acc
# cfp_ff datasets get 0.981 acc
# cfp_fp datasets get 0.912 acc
# cplfw datasets get 0.828 acc
# lfw_face datasets get 0.882 acc
# times:  191000
# time:  111551.28903436661
# times:  192000
# time:  112090.4137032032
# times:  193000
# time:  112630.82877397537
# times:  194000
# time:  113170.09609699249
# times:  195000
# time:  113709.96924090385
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.890 acc
# calfw datasets get 0.882 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.911 acc
# cplfw datasets get 0.822 acc
# lfw_face datasets get 0.879 acc
# times:  196000
# time:  114466.33062195778
# times:  197000
# time:  115004.25596928596
# times:  198000
# time:  115543.2208340168
# times:  199000
# time:  116082.37719321251
# times:  200000
# time:  116621.50878477097
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.896 acc
# calfw datasets get 0.894 acc
# cfp_ff datasets get 0.981 acc
# cfp_fp datasets get 0.907 acc
# cplfw datasets get 0.827 acc
# lfw_face datasets get 0.869 acc
# times:  201000
# time:  117378.05904436111
# times:  202000
# time:  117916.85774278641
# times:  203000
# time:  118457.09539484978
# times:  204000
# time:  118996.05268406868
# times:  205000
# time:  119535.05997920036
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.895 acc
# calfw datasets get 0.898 acc
# cfp_ff datasets get 0.984 acc
# cfp_fp datasets get 0.914 acc
# cplfw datasets get 0.831 acc
# lfw_face datasets get 0.881 acc
# times:  206000
# time:  120291.70757699013
# times:  207000
# time:  120830.53612017632
# times:  208000
# time:  121368.76617360115
# times:  209000
# time:  121907.85420513153
# times:  210000
# time:  122446.48718881607
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.891 acc
# calfw datasets get 0.883 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.910 acc
# cplfw datasets get 0.823 acc
# lfw_face datasets get 0.875 acc
# times:  211000
# time:  123225.07184481621
# times:  212000
# time:  123764.65549397469
# times:  213000
# time:  124302.99269723892
# times:  214000
# time:  124842.43124508858
# times:  215000
# time:  125381.60756659508
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.887 acc
# calfw datasets get 0.892 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.900 acc
# cplfw datasets get 0.825 acc
# lfw_face datasets get 0.870 acc
# times:  216000
# time:  126137.96374130249
# times:  217000
# time:  126675.46825122833
# times:  218000
# time:  127213.49364089966
# times:  219000
# time:  127753.56395959854
# times:  220000
# time:  128293.4642496109
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.899 acc
# calfw datasets get 0.888 acc
# cfp_ff datasets get 0.983 acc
# cfp_fp datasets get 0.917 acc
# cplfw datasets get 0.827 acc
# lfw_face datasets get 0.881 acc
# times:  221000
# time:  129050.17445111275
# times:  222000
# time:  129589.74976706505
# times:  223000
# time:  130128.95794916153
# times:  224000
# time:  130668.03549075127
# times:  225000
# time:  131205.9268233776
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.883 acc
# calfw datasets get 0.880 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.906 acc
# cplfw datasets get 0.821 acc
# lfw_face datasets get 0.881 acc
# times:  226000
# time:  131963.55680060387
# times:  227000
# time:  132502.6588640213
# times:  228000
# time:  133040.99689149857
# times:  229000
# time:  133580.34312653542
# times:  230000
# time:  134120.738915205
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.891 acc
# calfw datasets get 0.876 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.913 acc
# cplfw datasets get 0.820 acc
# lfw_face datasets get 0.876 acc
# times:  231000
# time:  134878.4666905403
# times:  232000
# time:  135416.45922780037
# times:  233000
# time:  135956.06125855446
# times:  234000
# time:  136496.37928509712
# times:  235000
# time:  137036.06544303894
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.890 acc
# calfw datasets get 0.890 acc
# cfp_ff datasets get 0.982 acc
# cfp_fp datasets get 0.904 acc
# cplfw datasets get 0.826 acc
# lfw_face datasets get 0.881 acc
# times:  236000
# time:  137794.38264656067
# times:  237000
# time:  138333.11421346664
# times:  238000
# time:  138872.16133999825
# times:  239000
# time:  139411.09510803223
# times:  240000
# time:  139950.0659520626
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.883 acc
# calfw datasets get 0.883 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.907 acc
# cplfw datasets get 0.825 acc
# lfw_face datasets get 0.872 acc
# times:  241000
# time:  140725.18691444397
# times:  242000
# time:  141263.39831757545
# times:  243000
# time:  141801.7475516796
# times:  244000
# time:  142339.64027881622
# times:  245000
# time:  142880.35176753998
# lfw datasets get 0.977 acc
# agedb_30 datasets get 0.884 acc
# calfw datasets get 0.877 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.913 acc
# cplfw datasets get 0.816 acc
# lfw_face datasets get 0.870 acc
# times:  246000
# time:  143637.6829726696
# times:  247000
# time:  144175.77125811577
# times:  248000
# time:  144714.039696455
# times:  249000
# time:  145254.90986299515
# times:  250000
# time:  145794.5578429699
# lfw datasets get 0.983 acc
# agedb_30 datasets get 0.883 acc
# calfw datasets get 0.884 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.910 acc
# cplfw datasets get 0.818 acc
# lfw_face datasets get 0.870 acc
# times:  251000
# time:  146552.84236335754
# times:  252000
# time:  147092.12320828438
# times:  253000
# time:  147632.33249902725
# times:  254000
# time:  148171.3992319107
# times:  255000
# time:  148710.20033216476
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.884 acc
# calfw datasets get 0.885 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.910 acc
# cplfw datasets get 0.824 acc
# lfw_face datasets get 0.881 acc
# times:  256000
# time:  149467.15719270706
# times:  257000
# time:  150006.70240020752
# times:  258000
# time:  150545.75397276878
# times:  259000
# time:  151084.78070259094
# times:  260000
# time:  151625.5230360031
# lfw datasets get 0.977 acc
# agedb_30 datasets get 0.885 acc
# calfw datasets get 0.875 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.909 acc
# cplfw datasets get 0.811 acc
# lfw_face datasets get 0.871 acc
# times:  261000
# time:  152382.88446688652
# times:  262000
# time:  152921.50773239136
# times:  263000
# time:  153459.73151254654
# times:  264000
# time:  153998.09760570526
# times:  265000
# time:  154536.74348807335
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.887 acc
# calfw datasets get 0.888 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.902 acc
# cplfw datasets get 0.823 acc
# lfw_face datasets get 0.868 acc
# times:  266000
# time:  155293.14797592163
# times:  267000
# time:  155831.49087619781
# times:  268000
# time:  156370.68795967102
# times:  269000
# time:  156922.86891889572
# times:  270000
# time:  157462.31888008118
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.889 acc
# calfw datasets get 0.887 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.909 acc
# cplfw datasets get 0.826 acc
# lfw_face datasets get 0.877 acc
# times:  271000
# time:  158238.8637764454
# times:  272000
# time:  158778.43224835396
# times:  273000
# time:  159317.22928762436
# times:  274000
# time:  159856.2473268509
# times:  275000
# time:  160395.595556736
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.876 acc
# calfw datasets get 0.880 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.911 acc
# cplfw datasets get 0.817 acc
# lfw_face datasets get 0.871 acc
# times:  276000
# time:  161153.45138955116
# times:  277000
# time:  161691.81440377235
# times:  278000
# time:  162230.89738678932
# times:  279000
# time:  162769.24378991127
# times:  280000
# time:  163308.61410856247
# lfw datasets get 0.978 acc
# agedb_30 datasets get 0.884 acc
# calfw datasets get 0.882 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.908 acc
# cplfw datasets get 0.810 acc
# lfw_face datasets get 0.865 acc
# times:  281000
# time:  164066.086997509
# times:  282000
# time:  164604.51793313026
# times:  283000
# time:  165143.33310747147
# times:  284000
# time:  165693.10308361053
# times:  285000
# time:  166232.6233394146
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.890 acc
# calfw datasets get 0.889 acc
# cfp_ff datasets get 0.982 acc
# cfp_fp datasets get 0.910 acc
# cplfw datasets get 0.827 acc
# lfw_face datasets get 0.877 acc
# times:  286000
# time:  166990.8084001541
# times:  287000
# time:  167529.80195093155
# times:  288000
# time:  168068.53909873962
# times:  289000
# time:  168606.9345164299
# times:  290000
# time:  169154.27819252014
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.882 acc
# calfw datasets get 0.886 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.902 acc
# cplfw datasets get 0.816 acc
# lfw_face datasets get 0.872 acc
# times:  291000
# time:  169912.10128688812
# times:  292000
# time:  170450.42118048668
# times:  293000
# time:  170988.98037433624
# times:  294000
# time:  171527.7392847538
# times:  295000
# time:  172066.67468309402
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.885 acc
# calfw datasets get 0.883 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.909 acc
# cplfw datasets get 0.816 acc
# lfw_face datasets get 0.871 acc
# times:  296000
# time:  172824.65280985832
# times:  297000
# time:  173362.2290751934
# times:  298000
# time:  173901.64044332504
# times:  299000
# time:  174441.52443432808
# times:  300000
# time:  174981.22070002556
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.887 acc
# calfw datasets get 0.885 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.904 acc
# cplfw datasets get 0.818 acc
# lfw_face datasets get 0.870 acc
# times:  301000
# time:  175763.1212360859
# times:  302000
# time:  176301.44482898712
# times:  303000
# time:  176839.60068941116
# times:  304000
# time:  177377.89766669273
# times:  305000
# time:  177917.10427331924
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.884 acc
# calfw datasets get 0.893 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.910 acc
# cplfw datasets get 0.821 acc
# lfw_face datasets get 0.874 acc
# times:  306000
# time:  178674.22027683258
# times:  307000
# time:  179213.20144462585
# times:  308000
# time:  179751.48109960556
# times:  309000
# time:  180290.55498480797
# times:  310000
# time:  180829.91273975372
# lfw datasets get 0.977 acc
# agedb_30 datasets get 0.885 acc
# calfw datasets get 0.880 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.911 acc
# cplfw datasets get 0.816 acc
# lfw_face datasets get 0.866 acc
# times:  311000
# time:  181586.83625125885
# times:  312000
# time:  182125.34569740295
# times:  313000
# time:  182686.0140657425
# times:  314000
# time:  183224.4410431385
# times:  315000
# time:  183760.93971300125
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.883 acc
# calfw datasets get 0.887 acc
# cfp_ff datasets get 0.976 acc
# cfp_fp datasets get 0.903 acc
# cplfw datasets get 0.822 acc
# lfw_face datasets get 0.871 acc
# times:  316000
# time:  184517.16547250748
# times:  317000
# time:  185055.73016238213
# times:  318000
# time:  185595.32897543907
# times:  319000
# time:  186134.1773364544
# times:  320000
# time:  186672.61356830597
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.889 acc
# calfw datasets get 0.889 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.910 acc
# cplfw datasets get 0.826 acc
# lfw_face datasets get 0.877 acc
# times:  321000
# time:  187430.7067949772
# times:  322000
# time:  187971.96107506752
# times:  323000
# time:  188510.2704834938
# times:  324000
# time:  189053.27680754662
# times:  325000
# time:  189591.23977422714
# lfw datasets get 0.976 acc
# agedb_30 datasets get 0.876 acc
# calfw datasets get 0.876 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.909 acc
# cplfw datasets get 0.815 acc
# lfw_face datasets get 0.868 acc
# times:  326000
# time:  190344.84426021576
# times:  327000
# time:  190880.4491353035
# times:  328000
# time:  191415.9441432953
# times:  329000
# time:  191953.1969115734
# times:  330000
# time:  192490.53045105934
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.886 acc
# calfw datasets get 0.878 acc
# cfp_ff datasets get 0.976 acc
# cfp_fp datasets get 0.904 acc
# cplfw datasets get 0.823 acc
# lfw_face datasets get 0.866 acc
# times:  331000
# time:  193263.408107996
# times:  332000
# time:  193798.75593471527
# times:  333000
# time:  194335.4664335251
# times:  334000
# time:  194871.8144645691
# times:  335000
# time:  195408.19070196152
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.890 acc
# calfw datasets get 0.890 acc
# cfp_ff datasets get 0.982 acc
# cfp_fp datasets get 0.909 acc
# cplfw datasets get 0.827 acc
# lfw_face datasets get 0.874 acc
# times:  336000
# time:  196161.09683203697
# times:  337000
# time:  196696.81422877312
# times:  338000
# time:  197231.99599313736
# times:  339000
# time:  197768.66857624054
# times:  340000
# time:  198303.8656246662
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.884 acc
# calfw datasets get 0.881 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.904 acc
# cplfw datasets get 0.820 acc
# lfw_face datasets get 0.871 acc
# times:  341000
# time:  199058.43332338333
# times:  342000
# time:  199594.43868207932
# times:  343000
# time:  200130.6978211403
# times:  344000
# time:  200667.46708488464
# times:  345000
# time:  201204.6483464241
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.884 acc
# calfw datasets get 0.887 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.911 acc
# cplfw datasets get 0.823 acc
# lfw_face datasets get 0.868 acc
# times:  346000
# time:  201956.73165988922
# times:  347000
# time:  202493.1275138855
# times:  348000
# time:  203030.24435663223
# times:  349000
# time:  203567.29427146912
# times:  350000
# time:  204103.38733959198
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.885 acc
# calfw datasets get 0.887 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.905 acc
# cplfw datasets get 0.824 acc
# lfw_face datasets get 0.867 acc
# times:  351000
# time:  204855.02671670914
# times:  352000
# time:  205391.03879761696
# times:  353000
# time:  205927.41192865372
# times:  354000
# time:  206463.2260131836
# times:  355000
# time:  206999.27555847168
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.885 acc
# calfw datasets get 0.887 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.906 acc
# cplfw datasets get 0.821 acc
# lfw_face datasets get 0.872 acc
# times:  356000
# time:  207751.69565224648
# times:  357000
# time:  208287.84053969383
# times:  358000
# time:  208823.20312595367
# times:  359000
# time:  209359.31762695312
# times:  360000
# time:  209895.45510578156
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.884 acc
# calfw datasets get 0.876 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.911 acc
# cplfw datasets get 0.816 acc
# lfw_face datasets get 0.868 acc
# times:  361000
# time:  210666.9820072651
# times:  362000
# time:  211203.15029096603
# times:  363000
# time:  211738.3081421852
# times:  364000
# time:  212274.2443470955
# times:  365000
# time:  212810.02823328972
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.887 acc
# calfw datasets get 0.885 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.903 acc
# cplfw datasets get 0.822 acc
# lfw_face datasets get 0.863 acc
# times:  366000
# time:  213561.72074198723
# times:  367000
# time:  214097.02960300446
# times:  368000
# time:  214633.40628290176
# times:  369000
# time:  215169.21674370766
# times:  370000
# time:  215705.10616922379
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.892 acc
# calfw datasets get 0.890 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.910 acc
# cplfw datasets get 0.824 acc
# lfw_face datasets get 0.879 acc
# times:  371000
# time:  216457.36413955688
# times:  372000
# time:  216992.74750232697
# times:  373000
# time:  217528.8721909523
# times:  374000
# time:  218065.42286634445
# times:  375000
# time:  218602.34392857552
# lfw datasets get 0.977 acc
# agedb_30 datasets get 0.879 acc
# calfw datasets get 0.875 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.907 acc
# cplfw datasets get 0.815 acc
# lfw_face datasets get 0.870 acc
# times:  376000
# time:  219353.45625042915
# times:  377000
# time:  219888.57454490662
# times:  378000
# time:  220423.58574604988
# times:  379000
# time:  220959.47010922432
# times:  380000
# time:  221497.62232923508
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.888 acc
# calfw datasets get 0.885 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.907 acc
# cplfw datasets get 0.825 acc
# lfw_face datasets get 0.866 acc
# times:  381000
# time:  222249.7284669876
# times:  382000
# time:  222784.2169532776
# times:  383000
# time:  223320.3057525158
# times:  384000
# time:  223855.12175226212
# times:  385000
# time:  224391.1509950161
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.889 acc
# calfw datasets get 0.887 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.906 acc
# cplfw datasets get 0.828 acc
# lfw_face datasets get 0.870 acc
# times:  386000
# time:  225142.1018357277
# times:  387000
# time:  225678.6473712921
# times:  388000
# time:  226214.06276392937
# times:  389000
# time:  226750.56874632835
# times:  390000
# time:  227286.09712958336
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.878 acc
# calfw datasets get 0.881 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.907 acc
# cplfw datasets get 0.819 acc
# lfw_face datasets get 0.873 acc
# times:  391000
# time:  228056.32589745522
# times:  392000
# time:  228591.01484370232
# times:  393000
# time:  229125.8748304844
# times:  394000
# time:  229659.49284172058
# times:  395000
# time:  230194.9866759777
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.887 acc
# calfw datasets get 0.885 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.904 acc
# cplfw datasets get 0.822 acc
# lfw_face datasets get 0.863 acc
# times:  396000
# time:  230947.4613852501
# times:  397000
# time:  231481.21852517128
# times:  398000
# time:  232015.21160316467
# times:  399000
# time:  232550.84869384766
# times:  400000
# time:  233086.77590489388
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.887 acc
# calfw datasets get 0.884 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.911 acc
# cplfw datasets get 0.823 acc
# lfw_face datasets get 0.867 acc
# times:  401000
# time:  233838.3126449585
# times:  402000
# time:  234372.8021941185
# times:  403000
# time:  234908.0305583477
# times:  404000
# time:  235443.64558243752
# times:  405000
# time:  235977.6408891678
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.886 acc
# calfw datasets get 0.882 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.903 acc
# cplfw datasets get 0.814 acc
# lfw_face datasets get 0.875 acc
# times:  406000
# time:  236729.4195933342
# times:  407000
# time:  237263.94094085693
# times:  408000
# time:  237799.03584122658
# times:  409000
# time:  238334.41035032272
# times:  410000
# time:  238870.01222205162
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.883 acc
# calfw datasets get 0.879 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.912 acc
# cplfw datasets get 0.819 acc
# lfw_face datasets get 0.868 acc
# times:  411000
# time:  239622.13792586327
# times:  412000
# time:  240157.33607172966
# times:  413000
# time:  240691.18513846397
# times:  414000
# time:  241227.00817632675
# times:  415000
# time:  241762.48959183693
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.889 acc
# calfw datasets get 0.885 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.904 acc
# cplfw datasets get 0.813 acc
# lfw_face datasets get 0.864 acc
# times:  416000
# time:  242513.04707193375
# times:  417000
# time:  243047.20448422432
# times:  418000
# time:  243584.77356266975
# times:  419000
# time:  244119.47425174713
# times:  420000
# time:  244654.42677044868
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.889 acc
# calfw datasets get 0.886 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.910 acc
# cplfw datasets get 0.815 acc
# lfw_face datasets get 0.876 acc
# times:  421000
# time:  245424.30506324768
# times:  422000
# time:  245958.19347453117
# times:  423000
# time:  246492.19872879982
# times:  424000
# time:  247027.69467878342
# times:  425000
# time:  247563.3475601673
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.881 acc
# calfw datasets get 0.875 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.910 acc
# cplfw datasets get 0.820 acc
# lfw_face datasets get 0.865 acc
# times:  426000
# time:  248315.78771734238
# times:  427000
# time:  248850.10535120964
# times:  428000
# time:  249384.7557477951
# times:  429000
# time:  249918.78072929382
# times:  430000
# time:  250455.2769358158
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.885 acc
# calfw datasets get 0.886 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.908 acc
# cplfw datasets get 0.822 acc
# lfw_face datasets get 0.868 acc
# times:  431000
# time:  251207.8662879467
# times:  432000
# time:  251742.80466532707
# times:  433000
# time:  252278.64223766327
# times:  434000
# time:  252813.5367217064
# times:  435000
# time:  253348.98293232918
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.894 acc
# calfw datasets get 0.888 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.910 acc
# cplfw datasets get 0.819 acc
# lfw_face datasets get 0.873 acc
# times:  436000
# time:  254100.3863761425
# times:  437000
# time:  254634.72757530212
# times:  438000
# time:  255170.63054275513
# times:  439000
# time:  255706.28613758087
# times:  440000
# time:  256241.69699406624
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.882 acc
# calfw datasets get 0.879 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.911 acc
# cplfw datasets get 0.820 acc
# lfw_face datasets get 0.872 acc
# times:  441000
# time:  256994.2261378765
# times:  442000
# time:  257528.56226921082
# times:  443000
# time:  258063.75387835503
# times:  444000
# time:  258599.21757936478
# times:  445000
# time:  259134.96573734283
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.883 acc
# calfw datasets get 0.882 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.907 acc
# cplfw datasets get 0.822 acc
# lfw_face datasets get 0.862 acc
# times:  446000
# time:  259886.5864367485
# times:  447000
# time:  260422.39675021172
# times:  448000
# time:  260956.50536727905
# times:  449000
# time:  261491.93137931824
# times:  450000
# time:  262027.20514678955
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.894 acc
# calfw datasets get 0.885 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.910 acc
# cplfw datasets get 0.825 acc
# lfw_face datasets get 0.871 acc
# times:  451000
# time:  262797.4452364445
# times:  452000
# time:  263333.2795789242
# times:  453000
# time:  263868.5505168438
# times:  454000
# time:  264404.88343191147
# times:  455000
# time:  264940.7976539135
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.879 acc
# calfw datasets get 0.881 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.906 acc
# cplfw datasets get 0.818 acc
# lfw_face datasets get 0.870 acc
# times:  456000
# time:  265692.58919119835
# times:  457000
# time:  266226.7874965668
# times:  458000
# time:  266761.9906051159
# times:  459000
# time:  267295.8678853512
# times:  460000
# time:  267832.47304725647
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.886 acc
# calfw datasets get 0.885 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.910 acc
# cplfw datasets get 0.827 acc
# lfw_face datasets get 0.870 acc
# times:  461000
# time:  268584.70614409447
# times:  462000
# time:  269143.29872870445
# times:  463000
# time:  269676.74203419685
# times:  464000
# time:  270211.5205054283
# times:  465000
# time:  270746.90727591515
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.887 acc
# calfw datasets get 0.880 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.903 acc
# cplfw datasets get 0.820 acc
# lfw_face datasets get 0.866 acc
# times:  466000
# time:  271499.68721818924
# times:  467000
# time:  272034.4965429306
# times:  468000
# time:  272569.5391652584
# times:  469000
# time:  273105.7129702568
# times:  470000
# time:  273640.5356602669
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.885 acc
# calfw datasets get 0.888 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.909 acc
# cplfw datasets get 0.816 acc
# lfw_face datasets get 0.872 acc
# times:  471000
# time:  274393.88141679764
# times:  472000
# time:  274929.2230889797
# times:  473000
# time:  275463.77757430077
# times:  474000
# time:  275999.154610157
# times:  475000
# time:  276535.35409903526
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.882 acc
# calfw datasets get 0.879 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.912 acc
# cplfw datasets get 0.818 acc
# lfw_face datasets get 0.868 acc
# times:  476000
# time:  277287.226657629
# times:  477000
# time:  277822.58871912956
# times:  478000
# time:  278358.1174607277
# times:  479000
# time:  278893.51609921455
# times:  480000
# time:  279430.00607943535
# lfw datasets get 0.983 acc
# agedb_30 datasets get 0.883 acc
# calfw datasets get 0.886 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.903 acc
# cplfw datasets get 0.815 acc
# lfw_face datasets get 0.865 acc
# times:  481000
# time:  280202.63963389397
# times:  482000
# time:  280736.98600268364
# times:  483000
# time:  281272.78638863564
# times:  484000
# time:  281809.53364658356
# times:  485000
# time:  282346.17962551117
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.888 acc
# calfw datasets get 0.892 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.906 acc
# cplfw datasets get 0.816 acc
# lfw_face datasets get 0.877 acc
# times:  486000
# time:  283099.46486258507
# times:  487000
# time:  283634.00900650024
# times:  488000
# time:  284168.7967879772
# times:  489000
# time:  284702.7184987068
# times:  490000
# time:  285237.0711326599
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.879 acc
# calfw datasets get 0.878 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.908 acc
# cplfw datasets get 0.816 acc
# lfw_face datasets get 0.871 acc
# times:  491000
# time:  285989.5581831932
# times:  492000
# time:  286524.7481737137
# times:  493000
# time:  287060.16328668594
# times:  494000
# time:  287595.40033984184
# times:  495000
# time:  288130.63502025604
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.888 acc
# calfw datasets get 0.884 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.907 acc
# cplfw datasets get 0.824 acc
# lfw_face datasets get 0.862 acc
# times:  496000
# time:  288880.93689084053
# times:  497000
# time:  289415.4436380863
# times:  498000
# time:  289950.80377697945
# times:  499000
# time:  290485.6396062374
# times:  500000
# time:  291021.55594825745
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.890 acc
# calfw datasets get 0.888 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.904 acc
# cplfw datasets get 0.821 acc
# lfw_face datasets get 0.876 acc
# times:  501000
# time:  291774.38452744484
# times:  502000
# time:  292309.7618224621
# times:  503000
# time:  292844.26513433456
# times:  504000
# time:  293379.3446998596
# times:  505000
# time:  293914.9059064388
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.876 acc
# calfw datasets get 0.881 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.906 acc
# cplfw datasets get 0.820 acc
# lfw_face datasets get 0.871 acc
# times:  506000
# time:  294666.4708559513
# times:  507000
# time:  295201.2108411789
# times:  508000
# time:  295736.23209095
# times:  509000
# time:  296269.9829668999
# times:  510000
# time:  296807.38892269135
# lfw datasets get 0.978 acc
# agedb_30 datasets get 0.885 acc
# calfw datasets get 0.883 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.906 acc
# cplfw datasets get 0.824 acc
# lfw_face datasets get 0.870 acc
# times:  511000
# time:  297578.57093143463
# times:  512000
# time:  298114.17245316505
# times:  513000
# time:  298649.7768931389
# times:  514000
# time:  299185.81807780266
# times:  515000
# time:  299722.3642985821
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.891 acc
# calfw datasets get 0.884 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.904 acc
# cplfw datasets get 0.823 acc
# lfw_face datasets get 0.863 acc
# times:  516000
# time:  300475.47095251083
# times:  517000
# time:  301010.2569630146
# times:  518000
# time:  301546.32480072975
# times:  519000
# time:  302082.6398618221
# times:  520000
# time:  302619.65138983727
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.880 acc
# calfw datasets get 0.885 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.905 acc
# cplfw datasets get 0.819 acc
# lfw_face datasets get 0.873 acc
# times:  521000
# time:  303371.433511734
# times:  522000
# time:  303906.348757267
# times:  523000
# time:  304441.6978507042
# times:  524000
# time:  304976.18376636505
# times:  525000
# time:  305511.9351258278
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.878 acc
# calfw datasets get 0.881 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.911 acc
# cplfw datasets get 0.819 acc
# lfw_face datasets get 0.871 acc
# times:  526000
# time:  306264.0964512825
# times:  527000
# time:  306799.25631046295
# times:  528000
# time:  307334.70364284515
# times:  529000
# time:  307870.6974453926
# times:  530000
# time:  308406.2688193321
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.882 acc
# calfw datasets get 0.882 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.906 acc
# cplfw datasets get 0.812 acc
# lfw_face datasets get 0.867 acc
# times:  531000
# time:  309157.5906329155
# times:  532000
# time:  309692.5620305538
# times:  533000
# time:  310228.7446632385
# times:  534000
# time:  310764.27013397217
# times:  535000
# time:  311300.4050114155
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.888 acc
# calfw datasets get 0.891 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.905 acc
# cplfw datasets get 0.820 acc
# lfw_face datasets get 0.871 acc
# times:  536000
# time:  312053.4802649021
# times:  537000
# time:  312589.076362133
# times:  538000
# time:  313124.2257359028
# times:  539000
# time:  313660.08052158356
# times:  540000
# time:  314195.3854677677
# lfw datasets get 0.976 acc
# agedb_30 datasets get 0.881 acc
# calfw datasets get 0.879 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.907 acc
# cplfw datasets get 0.811 acc
# lfw_face datasets get 0.868 acc
# times:  541000
# time:  314965.23279953003
# times:  542000
# time:  315500.67950081825
# times:  543000
# time:  316035.46247553825
# times:  544000
# time:  316571.6995265484
# times:  545000
# time:  317107.2311863899
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.883 acc
# calfw datasets get 0.880 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.904 acc
# cplfw datasets get 0.821 acc
# lfw_face datasets get 0.867 acc
# times:  546000
# time:  317858.32187247276
# times:  547000
# time:  318393.3781707287
# times:  548000
# time:  318929.4979119301
# times:  549000
# time:  319464.42745471
# times:  550000
# time:  320000.16250157356
# lfw datasets get 0.978 acc
# agedb_30 datasets get 0.892 acc
# calfw datasets get 0.889 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.904 acc
# cplfw datasets get 0.820 acc
# lfw_face datasets get 0.878 acc
# times:  551000
# time:  320752.64402365685
# times:  552000
# time:  321288.5200881958
# times:  553000
# time:  321823.9712500572
# times:  554000
# time:  322360.19943737984
# times:  555000
# time:  322895.8757493496
# lfw datasets get 0.977 acc
# agedb_30 datasets get 0.873 acc
# calfw datasets get 0.875 acc
# cfp_ff datasets get 0.976 acc
# cfp_fp datasets get 0.907 acc
# cplfw datasets get 0.812 acc
# lfw_face datasets get 0.867 acc
# times:  556000
# time:  323649.12184000015
# times:  557000
# time:  324184.4593408108
# times:  558000
# time:  324722.4542424679
# times:  559000
# time:  325260.2289202213
# times:  560000
# time:  325796.80657863617
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.886 acc
# calfw datasets get 0.889 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.903 acc
# cplfw datasets get 0.823 acc
# lfw_face datasets get 0.861 acc
# times:  561000
# time:  326549.6052188873
# times:  562000
# time:  327085.3715338707
# times:  563000
# time:  327621.91839432716
# times:  564000
# time:  328157.9039428234
# times:  565000
# time:  328693.60362935066
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.890 acc
# calfw datasets get 0.889 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.907 acc
# cplfw datasets get 0.831 acc
# lfw_face datasets get 0.871 acc
# times:  566000
# time:  329446.7433049679
# times:  567000
# time:  330002.1773121357
# times:  568000
# time:  330538.9748749733
# times:  569000
# time:  331074.52059197426
# times:  570000
# time:  331611.7462468147
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.879 acc
# calfw datasets get 0.887 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.906 acc
# cplfw datasets get 0.818 acc
# lfw_face datasets get 0.869 acc
# times:  571000
# time:  332383.7234790325
# times:  572000
# time:  332920.06810355186
# times:  573000
# time:  333455.50314736366
# times:  574000
# time:  333992.04651379585
# times:  575000
# time:  334529.69946217537
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.880 acc
# calfw datasets get 0.882 acc
# cfp_ff datasets get 0.978 acc
# ...
# times:  765000
# time:  444759.8717985153
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.890 acc
# calfw datasets get 0.892 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.904 acc
# cplfw datasets get 0.820 acc
# lfw_face datasets get 0.875 acc
# times:  766000
# time:  445511.7568964958
# times:  767000
# time:  446047.3096983433
# times:  768000
# time:  446582.03067970276
# times:  769000
# time:  447117.6524810791
# times:  770000
# time:  447653.42307400703
# lfw datasets get 0.977 acc
# agedb_30 datasets get 0.880 acc
# calfw datasets get 0.876 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.905 acc
# cplfw datasets get 0.816 acc
# lfw_face datasets get 0.861 acc
# times:  771000
# time:  448404.24214172363
# times:  772000
# time:  448939.25609850883
# times:  773000
# time:  449475.94634246826
# times:  774000
# time:  450011.8015630245
# times:  775000
# time:  450547.3108482361
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.886 acc
# calfw datasets get 0.885 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.903 acc
# cplfw datasets get 0.819 acc
# lfw_face datasets get 0.860 acc
# times:  776000
# time:  451300.16865968704
# times:  777000
# time:  451835.3541383743
# times:  778000
# time:  452371.4291527271
# times:  779000
# time:  452905.87651491165
# times:  780000
# time:  453440.64136743546
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.891 acc
# calfw datasets get 0.888 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.908 acc
# cplfw datasets get 0.823 acc
# lfw_face datasets get 0.874 acc
# times:  781000
# time:  454211.6813688278
# times:  782000
# time:  454747.48935198784
# times:  783000
# time:  455282.3360924721
# times:  784000
# time:  455817.99411940575
# times:  785000
# time:  456353.92616677284
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.871 acc
# calfw datasets get 0.881 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.906 acc
# cplfw datasets get 0.820 acc
# lfw_face datasets get 0.864 acc
# times:  786000
# time:  457106.7205235958
# times:  787000
# time:  457642.16678094864
# times:  788000
# time:  458176.974306345
# times:  789000
# time:  458712.95076322556
# times:  790000
# time:  459248.831795454
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.886 acc
# calfw datasets get 0.883 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.907 acc
# cplfw datasets get 0.820 acc
# lfw_face datasets get 0.860 acc
# times:  791000
# time:  460001.64704084396
# times:  792000
# time:  460536.9057831764
# times:  793000
# time:  461072.29625725746
# times:  794000
# time:  461607.9886138439
# times:  795000
# time:  462144.18343925476
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.890 acc
# calfw datasets get 0.880 acc
# cfp_ff datasets get 0.981 acc
# cfp_fp datasets get 0.908 acc
# cplfw datasets get 0.823 acc
# lfw_face datasets get 0.869 acc
# times:  796000
# time:  462895.6436638832
# times:  797000
# time:  463431.0734779835
# times:  798000
# time:  463965.2667198181
# times:  799000
# time:  464500.9242298603
# times:  800000
# time:  465036.8528599739
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.878 acc
# calfw datasets get 0.883 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.906 acc
# cplfw datasets get 0.817 acc
# lfw_face datasets get 0.861 acc
# times:  801000
# time:  465788.4464726448
# times:  802000
# time:  466322.47972750664
# times:  803000
# time:  466857.70747327805
# times:  804000
# time:  467392.72637319565
# times:  805000
# time:  467928.9157040119
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.881 acc
# calfw datasets get 0.881 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.911 acc
# cplfw datasets get 0.818 acc
# lfw_face datasets get 0.868 acc
# times:  806000
# time:  468680.72325348854
# times:  807000
# time:  469215.5679895878
# times:  808000
# time:  469750.06868338585
# times:  809000
# time:  470285.22822856903
# times:  810000
# time:  470820.28262901306
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.888 acc
# calfw datasets get 0.884 acc
# cfp_ff datasets get 0.981 acc
# cfp_fp datasets get 0.904 acc
# cplfw datasets get 0.824 acc
# lfw_face datasets get 0.869 acc
# times:  811000
# time:  471592.3488020897
# times:  812000
# time:  472127.19596004486
# times:  813000
# time:  472661.48285245895
# times:  814000
# time:  473196.8245666027
# times:  815000
# time:  473732.63667964935
# lfw datasets get 0.978 acc
# agedb_30 datasets get 0.887 acc
# calfw datasets get 0.889 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.903 acc
# cplfw datasets get 0.815 acc
# lfw_face datasets get 0.868 acc
# times:  816000
# time:  474483.0434241295
# times:  817000
# time:  475018.68563604355
# times:  818000
# time:  475553.1986055374
# times:  819000
# time:  476087.46860837936
# times:  820000
# time:  476623.9090921879
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.877 acc
# calfw datasets get 0.879 acc
# cfp_ff datasets get 0.976 acc
# cfp_fp datasets get 0.908 acc
# cplfw datasets get 0.823 acc
# lfw_face datasets get 0.865 acc
# times:  821000
# time:  477374.65588998795
# times:  822000
# time:  477908.4901025295
# times:  823000
# time:  478443.56675696373
# times:  824000
# time:  478977.090886116
# times:  825000
# time:  479511.2210304737
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.882 acc
# calfw datasets get 0.879 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.905 acc
# cplfw datasets get 0.820 acc
# lfw_face datasets get 0.863 acc
# times:  826000
# time:  480262.62180638313
# times:  827000
# time:  480797.2024374008
# times:  828000
# time:  481332.0325653553
# times:  829000
# time:  481867.29443383217
# times:  830000
# time:  482403.00813508034
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.891 acc
# calfw datasets get 0.891 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.905 acc
# cplfw datasets get 0.822 acc
# lfw_face datasets get 0.878 acc
# times:  831000
# time:  483152.7904446125
# times:  832000
# time:  483686.9522192478
# times:  833000
# time:  484222.11207938194
# times:  834000
# time:  484756.79669213295
# times:  835000
# time:  485291.3656117916
# lfw datasets get 0.978 acc
# agedb_30 datasets get 0.876 acc
# calfw datasets get 0.871 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.905 acc
# cplfw datasets get 0.819 acc
# lfw_face datasets get 0.867 acc
# times:  836000
# time:  486041.9002456665
# times:  837000
# time:  486576.91988039017
# times:  838000
# time:  487111.393904686
# times:  839000
# time:  487646.88650512695
# times:  840000
# time:  488181.9983522892
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.886 acc
# calfw datasets get 0.882 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.907 acc
# cplfw datasets get 0.821 acc
# lfw_face datasets get 0.859 acc
# times:  841000
# time:  488952.1234052181
# times:  842000
# time:  489485.45181679726
# times:  843000
# time:  490020.80193185806
# times:  844000
# time:  490554.87107276917
# times:  845000
# time:  491088.75794506073
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.887 acc
# calfw datasets get 0.885 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.904 acc
# cplfw datasets get 0.821 acc
# lfw_face datasets get 0.876 acc
# times:  846000
# time:  491840.5879366398
# times:  847000
# time:  492374.4950413704
# times:  848000
# time:  492909.03537392616
# times:  849000
# time:  493441.93939614296
# times:  850000
# time:  493976.03070163727
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.875 acc
# calfw datasets get 0.878 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.903 acc
# cplfw datasets get 0.815 acc
# lfw_face datasets get 0.863 acc
# times:  851000
# time:  494727.34051823616
# times:  852000
# time:  495261.93240070343
# times:  853000
# time:  495795.9315984249
# times:  854000
# time:  496329.65759158134
# times:  855000
# time:  496864.257976532
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.885 acc
# calfw datasets get 0.877 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.905 acc
# cplfw datasets get 0.818 acc
# lfw_face datasets get 0.863 acc
# times:  856000
# time:  497615.2115921974
# times:  857000
# time:  498150.31619381905
# times:  858000
# time:  498684.49223423004
# times:  859000
# time:  499218.43131661415
# times:  860000
# time:  499753.34329104424
# lfw datasets get 0.982 acc
# agedb_30 datasets get 0.893 acc
# calfw datasets get 0.886 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.906 acc
# cplfw datasets get 0.817 acc
# lfw_face datasets get 0.871 acc
# times:  861000
# time:  500505.37360715866
# times:  862000
# time:  501040.24979639053
# times:  863000
# time:  501574.8700864315
# times:  864000
# time:  502108.44913339615
# times:  865000
# time:  502644.21276307106
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.882 acc
# calfw datasets get 0.880 acc
# cfp_ff datasets get 0.980 acc
# cfp_fp datasets get 0.904 acc
# cplfw datasets get 0.817 acc
# lfw_face datasets get 0.864 acc
# times:  866000
# time:  503395.663408041
# times:  867000
# time:  503930.2626724243
# times:  868000
# time:  504463.92969727516
# times:  869000
# time:  504998.62285375595
# times:  870000
# time:  505533.5154566765
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.881 acc
# calfw datasets get 0.874 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.910 acc
# cplfw datasets get 0.820 acc
# lfw_face datasets get 0.868 acc
# times:  871000
# time:  506304.3434398174
# times:  872000
# time:  506838.3595793247
# times:  873000
# time:  507373.2619829178
# times:  874000
# time:  507908.1314136982
# times:  875000
# time:  508442.5685210228
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.884 acc
# calfw datasets get 0.885 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.908 acc
# cplfw datasets get 0.819 acc
# lfw_face datasets get 0.866 acc
# times:  876000
# time:  509194.04099702835
# times:  877000
# time:  509728.26487469673
# times:  878000
# time:  510262.47699809074
# times:  879000
# time:  510795.1576063633
# times:  880000
# time:  511330.0080435276
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.889 acc
# calfw datasets get 0.888 acc
# cfp_ff datasets get 0.979 acc
# cfp_fp datasets get 0.901 acc
# cplfw datasets get 0.821 acc
# lfw_face datasets get 0.877 acc
# times:  881000
# time:  512081.122477293
# times:  882000
# time:  512615.1177043915
# times:  883000
# time:  513148.5025649071
# times:  884000
# time:  513683.31673431396
# times:  885000
# time:  514217.5823857784
# lfw datasets get 0.977 acc
# agedb_30 datasets get 0.877 acc
# calfw datasets get 0.879 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.904 acc
# cplfw datasets get 0.819 acc
# lfw_face datasets get 0.865 acc
# times:  886000
# time:  514966.693154335
# times:  887000
# time:  515499.48813700676
# times:  888000
# time:  516033.5007889271
# times:  889000
# time:  516567.21457386017
# times:  890000
# time:  517102.0068964958
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.885 acc
# calfw datasets get 0.884 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.906 acc
# cplfw datasets get 0.823 acc
# lfw_face datasets get 0.861 acc
# times:  891000
# time:  517853.49814867973
# times:  892000
# time:  518387.1241247654
# times:  893000
# time:  518922.6213502884
# times:  894000
# time:  519456.20566916466
# times:  895000
# time:  519989.362074852
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.887 acc
# calfw datasets get 0.886 acc
# cfp_ff datasets get 0.981 acc
# cfp_fp datasets get 0.902 acc
# cplfw datasets get 0.815 acc
# lfw_face datasets get 0.874 acc
# times:  896000
# time:  520740.40788531303
# times:  897000
# time:  521273.7773902416
# times:  898000
# time:  521806.9630625248
# times:  899000
# time:  522340.1413769722
# times:  900000
# time:  522874.2444908619
# lfw datasets get 0.977 acc
# agedb_30 datasets get 0.877 acc
# calfw datasets get 0.879 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.901 acc
# cplfw datasets get 0.819 acc
# lfw_face datasets get 0.867 acc
# times:  901000
# time:  523644.3012678623
# times:  902000
# time:  524178.50917220116
# times:  903000
# time:  524712.9828300476
# times:  904000
# time:  525246.8427066803
# times:  905000
# time:  525782.444631815
# lfw datasets get 0.979 acc
# agedb_30 datasets get 0.880 acc
# calfw datasets get 0.881 acc
# cfp_ff datasets get 0.977 acc
# cfp_fp datasets get 0.905 acc
# cplfw datasets get 0.815 acc
# lfw_face datasets get 0.861 acc
# times:  906000
# time:  526533.6879098415
# times:  907000
# time:  527066.7063879967
# times:  908000
# time:  527601.6667113304
# times:  909000
# time:  528153.5575778484
# times:  910000
# time:  528686.7165834904
# lfw datasets get 0.980 acc
# agedb_30 datasets get 0.888 acc
# calfw datasets get 0.884 acc
# cfp_ff datasets get 0.981 acc
# cfp_fp datasets get 0.905 acc
# cplfw datasets get 0.822 acc
# lfw_face datasets get 0.866 acc
# times:  911000
# time:  529437.1374855042
# times:  912000
# time:  529970.6697044373
# times:  913000
# time:  530504.181229353
# times:  914000
# time:  531038.6200911999
# times:  915000
# time:  531573.8044435978
# lfw datasets get 0.981 acc
# agedb_30 datasets get 0.872 acc
# calfw datasets get 0.881 acc
# cfp_ff datasets get 0.978 acc
# cfp_fp datasets get 0.907 acc
# cplfw datasets get 0.819 acc
# lfw_face datasets get 0.866 acc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8d34b041f65a> in <module>()
#     153     f = open("./eval_record.txt", 'w')
#     154     f.write("\t dataset \t accuracy \t best_thresholds \t"+'\n')
# --> 155     main()
#     156 # tensorboard --logdir=/home/dell/Desktop/insightface/model/Arcface_model/
#
# <ipython-input-1-8d34b041f65a> in main()
#     136         issame_list_batch.append(issame_list)
#     137
# --> 138     train(image,label, train_phase_dropout, train_phase_bn, images_batch, images_f_batch, issame_list_batch)
#     139
#     140
#
# <ipython-input-1-8d34b041f65a> in train(image, label, train_phase_dropout, train_phase_bn, images_batch, images_f_batch, issame_list_batch)
#      88             for i in range(1,train_step):
#      89                 image_batch,label_batch=sess.run([train_images,train_labels])
# ---> 90                 sess.run([train_op,inc_op],feed_dict={image:image_batch,label:label_batch,train_phase_dropout:True,train_phase_bn:True})
#      91
#      92                 if(i%100==0):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
